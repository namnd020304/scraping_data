    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "vi-VN,vi;q=0.9,en;q=0.8",
    "Accept-Encoding": "gzip, deflate, br",
    "Content-Type": "application/json",
    "Referer": "https://tiki.vn/dien-thoai-may-tinh-bang/c1789",
    "Origin": "https://tiki.vn",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin"
}

# PARAMETERS - Query parameters trong URL
PARAMS = {
    "limit": 40,
    "include": "advertisement",
    "aggregations": "{i}",  # Placeholder để format khi scrape
    "version": "home-persionalized", 
    "trackity_id": "66b12662-c9ef-d3c5-8508-3b227e3e42bf",
    "category": 1789,
    "page": "{i}",  # Placeholder để format page number khi scrape
    "urlKey": "dien-thoai-may-tinh-bang"
}

# BASE URL
BASE_URL = "https://tiki.vn/api/personalish/v1/blocks/listings"

# %%
import requests
from urllib.parse import urlencode

def build_tiki_url(page=1):
    """Xây dựng URL với page number cụ thể"""
    # Format parameters với page number
    formatted_params = {
        "limit": 40,
        "include": "advertisement", 
        "aggregations": page,  # Sử dụng page number
        "version": "home-persionalized",
        "trackity_id": "66b12662-c9ef-d3c5-8508-3b227e3e42bf",
        "category": 1789,
        "page": page,  # Page number thực tế
        "urlKey": "dien-thoai-may-tinh-bang"
    }
    
    query_string = urlencode(formatted_params)
    return f"{BASE_URL}?{query_string}"

# %%
def scrape_multiple_pages(max_pages=5):
    """Scrape nhiều trang"""
    all_data = []
    
    for page in range(1, max_pages + 1):
        url = build_tiki_url(page)
        response = requests.get(url, headers=HEADERS)
        
        if response.status_code == 200:
            data = response.json()
            all_data.append(data)
            print(f"Scraped page {page} successfully")
        else:
            print(f"Failed to scrape page {page}")
    
    return all_data

# %%
data = scrape_multiple_pages(5)
# Out:
# Scraped page 1 successfully
# Scraped page 2 successfully
# Scraped page 3 successfully
# Scraped page 4 successfully
# Scraped page 5 successfully

# %%
data[1]
# Out:
# {'block': {'code': 'tiki_listing', 'title': 'Tiki Listing', 'icon': ''},
#  'data': [{'id': 277068413,
#    'sku': '5492892023430',
#    'name': 'Điện thoại Samsung Galaxy S25 Ultra, Điện thoại AI, Tìm kiếm thông minh, Video camera đêm Nightography, S Pen đa nhiệm - Hàng Chính Hãng',
#    'url_key': 'dien-thoai-samsung-galaxy-s25-ultra-dien-thoai-ai-tim-kiem-thong-minh-video-camera-dem-nightography-s-pen-da-nhiem-hang-chinh-hang-p277068413',
#    'url_path': 'dien-thoai-samsung-galaxy-s25-ultra-dien-thoai-ai-tim-kiem-thong-minh-video-camera-dem-nightography-s-pen-da-nhiem-hang-chinh-hang-p277068413.html?spid=277068431',
#    'type': '',
#    'author_name': '',
#    'book_cover': None,
#    'brand_name': 'Samsung',
#    'short_description': '',
#    'price': 28990000,
#    'list_price': 0,
#    'badges': [],
#    'badges_new': [{'code': 'tikinow',
#      'icon': 'https://salt.tikicdn.com/ts/tka/a8/31/b6/802e2c99dcce64c67aa2648edb15dd25.png',
#      'icon_height': 16,
# ...
